# %%
import numpy as np

# %% [markdown]
# Her har jeg importert "numpy" pakken og har valgt at jeg skal kalle den "np" resten av scriptet.
# så den kan den brukes som dette

# %%
np.random.random(2)
# Out:
# array([ 0.75744928,  0.25779459])

# %% [markdown]
# Nå brukte jeg "random" pakken inne i "numpy" for å hente ut 2 tilfeldige tall mellom 0 og 1.
# Du kan få et nesten vilkårlig mange tilfeldige tall

# %%
a = np.random.random(100)
print(len(a),a) #len() er for å sjekke hvor mange element som er inneholdt i variabelen a
# Out:
# 100 [ 0.42785196  0.01751185  0.41763257  0.41878931  0.33998779  0.651382
#   0.9184632   0.86145206  0.62193661  0.36352248  0.82131101  0.5325342
#   0.12480818  0.05772792  0.34210231  0.32419847  0.886698    0.83236347
#   0.46448041  0.26047997  0.13629214  0.35950394  0.00441437  0.17547269
#   0.96756404  0.88018745  0.38007771  0.63383875  0.4133315   0.63944886
#   0.05293209  0.31138149  0.33927785  0.57934802  0.02530135  0.52773558
#   0.23400055  0.88536835  0.5424775   0.75099378  0.43579457  0.72340263
#   0.20705512  0.47395875  0.21420354  0.02884692  0.47112198  0.91016177
#   0.34119303  0.16561471  0.69660092  0.72508439  0.16085224  0.72470851
#   0.61922733  0.99062719  0.84308556  0.7113715   0.62218367  0.92846341
#   0.87215815  0.40559262  0.63046861  0.97471429  0.02681295  0.88451383
#   0.19176952  0.94966472  0.29211438  0.83867086  0.96552334  0.24806157
#   0.27700733  0.84928419  0.26399183  0.72181171  0.6026938   0.32415303
# ...

# %% [markdown]
# så kan vi prøve å lage noe mer visuelt for å se om det faktisk er tilfeldig ved å bruke for eksempel
# matplotlib, en modul som lager grafer for deg

# %%
import matplotlib.pyplot as plt
plt.plot(a)
plt.show()

# %%
np.mean(a) #finner gjennomsnittet av alle tallene inneholdt i variabelen a
# Out:
# 0.52296668430180482

# %% [markdown]
# her ser vi at snittet ligger ganske bra mot 0.5, midten av fordelingen.
# vi kan lage flere tilfeldige tall for at snittet skal komme nærmere 0.5

# %%
for i in range(9):
    print(np.mean(np.random.random(10**i)))
# Out:
# 0.204878660102
# 0.528307629266
# 0.504901028109
# 0.494731105422
# 0.502250377608
# 0.499142725035
# 0.499911164897
# 0.499983613552
# 0.500016681324

# %% [markdown]
# Som vi ser går snittet nærmere og nærmere midten av fordelingen.
